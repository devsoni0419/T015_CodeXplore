# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Ouput.csv")

# %%
df['Target'].unique()
# Out:
# array([0, 1])

# %%
df = df.iloc[:,1:]

# %%
df
# Out:
#       Application order  Course  Daytime/evening attendance  \
# 0                     5       2                           1
# 1                     2      15                           1
# 2                     1      12                           1
# 3                     1      14                           1
# 4                     1      12                           1
# ...                 ...     ...                         ...
# 2432                  1       8                           1
# 2433                  1       5                           1
# 2434                  6      15                           1
# 2435                  1      12                           1
# 2436                  1       9                           1
#
#       Mother's occupation  Father's occupation  Displaced  \
# 0                       6                   10          1
# 1                       6                    4          1
# 2                       8                   11          1
# 3                       6                    8          1
# 4                      10                   10          1
# ...                   ...                  ...        ...
# 2432                    4                    6          1
# 2433                   10                   10          1
# 2434                    6                    5          0
# 2435                   10                   10          1
# 2436                    8                    5          1
#
#       Tuition fees up to date  Scholarship holder  International  \
# 0                           1                   0              0
# 1                           1                   0              0
# 2                           1                   1              0
# 3                           1                   0              0
# 4                           1                   1              0
# ...                       ...                 ...            ...
# 2432                        1                   0              0
# 2433                        1                   1              0
# 2434                        1                   0              0
# 2435                        1                   1              0
# 2436                        1                   1              0
#
#       Curricular units 1st sem (credited)  ...  \
# 0                                       0  ...
# 1                                       0  ...
# 2                                       0  ...
# 3                                       0  ...
# 4                                       0  ...
# ...                                   ...  ...
# 2432                                    0  ...
# 2433                                    0  ...
# 2434                                    0  ...
# 2435                                    0  ...
# 2436                                    0  ...
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.428571
# 2                                       7                         13.300000
# 3                                       6                         12.333333
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.800000
# 2433                                    6                         13.833333
# 2434                                    5                         13.600000
# 2435                                    7                         14.912500
# 2436                                    5                         13.800000
#
#       Curricular units 2nd sem (credited)  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 2432                                    0
# 2433                                    0
# 2434                                    0
# 2435                                    0
# 2436                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       8
# 3                                       6
# 4                                       8
# ...                                   ...
# 2432                                    5
# 2433                                    6
# 2434                                    6
# 2435                                    8
# 2436                                    5
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                         10
# 2                                          8
# 3                                          7
# 4                                          8
# ...                                      ...
# 2432                                       8
# 2433                                       6
# 2434                                       8
# 2435                                       9
# 2436                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       5                         12.400000
# 2                                       8                         14.345000
# 3                                       5                         14.200000
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.600000
# 2433                                    6                         13.500000
# 2434                                    5                         12.666667
# 2435                                    1                         13.500000
# 2436                                    5                         12.000000
#
#       Unemployment rate   GDP  Target
# 0                  10.8  1.74       0
# 1                   9.4 -3.12       1
# 2                  15.5 -4.06       1
# 3                  13.9  0.79       1
# 4                  12.7 -1.70       1
# ...                 ...   ...     ...
# 2432                9.4 -3.12       1
# 2433               16.2 -0.92       1
# 2434               15.5 -4.06       1
# 2435               13.9  0.79       0
# 2436                9.4 -3.12       1
#
# [2437 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2437 entries, 0 to 2436
# Data columns (total 22 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Application order                       2437 non-null   int64
#  1   Course                                  2437 non-null   int64
#  2   Daytime/evening attendance              2437 non-null   int64
#  3   Mother's occupation                     2437 non-null   int64
#  4   Father's occupation                     2437 non-null   int64
#  5   Displaced                               2437 non-null   int64
#  6   Tuition fees up to date                 2437 non-null   int64
#  7   Scholarship holder                      2437 non-null   int64
#  8   International                           2437 non-null   int64
#  9   Curricular units 1st sem (credited)     2437 non-null   int64
#  10  Curricular units 1st sem (enrolled)     2437 non-null   int64
#  11  Curricular units 1st sem (evaluations)  2437 non-null   int64
#  12  Curricular units 1st sem (approved)     2437 non-null   int64
#  13  Curricular units 1st sem (grade)        2437 non-null   float64
#  14  Curricular units 2nd sem (credited)     2437 non-null   int64
#  15  Curricular units 2nd sem (enrolled)     2437 non-null   int64
#  16  Curricular units 2nd sem (evaluations)  2437 non-null   int64
#  17  Curricular units 2nd sem (approved)     2437 non-null   int64
#  18  Curricular units 2nd sem (grade)        2437 non-null   float64
#  19  Unemployment rate                       2437 non-null   float64
#  20  GDP                                     2437 non-null   float64
#  21  Target                                  2437 non-null   int64
# dtypes: float64(4), int64(18)
# memory usage: 419.0 KB

# %%
df.isnull().sum()
# Out:
# Application order                         0
# Course                                    0
# Daytime/evening attendance                0
# Mother's occupation                       0
# Father's occupation                       0
# Displaced                                 0
# Tuition fees up to date                   0
# Scholarship holder                        0
# International                             0
# Curricular units 1st sem (credited)       0
# Curricular units 1st sem (enrolled)       0
# Curricular units 1st sem (evaluations)    0
# Curricular units 1st sem (approved)       0
# Curricular units 1st sem (grade)          0
# Curricular units 2nd sem (credited)       0
# Curricular units 2nd sem (enrolled)       0
# Curricular units 2nd sem (evaluations)    0
# Curricular units 2nd sem (approved)       0
# Curricular units 2nd sem (grade)          0
# Unemployment rate                         0
# GDP                                       0
# Target                                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df.sample()
# Out:
#       Application order  Course  Daytime/evening attendance  \
# 1327                  1      14                           1
#
#       Mother's occupation  Father's occupation  Displaced  \
# 1327                    4                    4          0
#
#       Tuition fees up to date  Scholarship holder  International  \
# 1327                        1                   1              0
#
#       Curricular units 1st sem (credited)  ...  \
# 1327                                    0  ...
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 1327                                    0                               0.0
#
#       Curricular units 2nd sem (credited)  \
# 1327                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 1327                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 1327                                       0
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 1327                                    0                               0.0
#
#       Unemployment rate   GDP  Target
# 1327               12.4  1.79       0
#
# [1 rows x 22 columns]

# %%
df.shape
# Out:
# (2437, 22)

# %%
df
# Out:
#       Application order  Course  Daytime/evening attendance  \
# 0                     5       2                           1
# 1                     2      15                           1
# 2                     1      12                           1
# 3                     1      14                           1
# 4                     1      12                           1
# ...                 ...     ...                         ...
# 2432                  1       8                           1
# 2433                  1       5                           1
# 2434                  6      15                           1
# 2435                  1      12                           1
# 2436                  1       9                           1
#
#       Mother's occupation  Father's occupation  Displaced  \
# 0                       6                   10          1
# 1                       6                    4          1
# 2                       8                   11          1
# 3                       6                    8          1
# 4                      10                   10          1
# ...                   ...                  ...        ...
# 2432                    4                    6          1
# 2433                   10                   10          1
# 2434                    6                    5          0
# 2435                   10                   10          1
# 2436                    8                    5          1
#
#       Tuition fees up to date  Scholarship holder  International  \
# 0                           1                   0              0
# 1                           1                   0              0
# 2                           1                   1              0
# 3                           1                   0              0
# 4                           1                   1              0
# ...                       ...                 ...            ...
# 2432                        1                   0              0
# 2433                        1                   1              0
# 2434                        1                   0              0
# 2435                        1                   1              0
# 2436                        1                   1              0
#
#       Curricular units 1st sem (credited)  ...  \
# 0                                       0  ...
# 1                                       0  ...
# 2                                       0  ...
# 3                                       0  ...
# 4                                       0  ...
# ...                                   ...  ...
# 2432                                    0  ...
# 2433                                    0  ...
# 2434                                    0  ...
# 2435                                    0  ...
# 2436                                    0  ...
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.428571
# 2                                       7                         13.300000
# 3                                       6                         12.333333
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.800000
# 2433                                    6                         13.833333
# 2434                                    5                         13.600000
# 2435                                    7                         14.912500
# 2436                                    5                         13.800000
#
#       Curricular units 2nd sem (credited)  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 2432                                    0
# 2433                                    0
# 2434                                    0
# 2435                                    0
# 2436                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       8
# 3                                       6
# 4                                       8
# ...                                   ...
# 2432                                    5
# 2433                                    6
# 2434                                    6
# 2435                                    8
# 2436                                    5
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                         10
# 2                                          8
# 3                                          7
# 4                                          8
# ...                                      ...
# 2432                                       8
# 2433                                       6
# 2434                                       8
# 2435                                       9
# 2436                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       5                         12.400000
# 2                                       8                         14.345000
# 3                                       5                         14.200000
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.600000
# 2433                                    6                         13.500000
# 2434                                    5                         12.666667
# 2435                                    1                         13.500000
# 2436                                    5                         12.000000
#
#       Unemployment rate   GDP  Target
# 0                  10.8  1.74       0
# 1                   9.4 -3.12       1
# 2                  15.5 -4.06       1
# 3                  13.9  0.79       1
# 4                  12.7 -1.70       1
# ...                 ...   ...     ...
# 2432                9.4 -3.12       1
# 2433               16.2 -0.92       1
# 2434               15.5 -4.06       1
# 2435               13.9  0.79       0
# 2436                9.4 -3.12       1
#
# [2437 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
df.shape
# Out:
# (2437, 22)

# %%
X = df.drop('Target', axis=1)
y = df['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

Names=list(X_train.columns.values)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.70496254, -0.07519095,  0.        , ...,  0.07347614,
#          0.40444762, -0.79492647],
#        [-0.67536003, -0.07519095,  0.        , ...,  0.29259277,
#         -0.20877595,  0.88378038],
#        [-0.67536003, -1.41776905,  0.        , ...,  0.30354861,
#          0.40444762, -0.79492647],
#        ...,
#        [-0.67536003, -1.14925343,  0.        , ...,  0.49527566,
#         -1.55020249,  0.1166294 ],
#        [-0.67536003,  1.26738714,  0.        , ...,  0.40899849,
#         -0.20877595,  0.88378038],
#        [-0.67536003,  0.46184028,  0.        , ...,  0.07028069,
#         -1.55020249,  0.1166294 ]], shape=(1632, 21))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9006211180124224

# %%
lr.predict(X_test[0].reshape(1,-1))
# Out:
# array([1])

# %%
df.columns
# Out:
# Index(['Application order', 'Course', 'Daytime/evening attendance',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Tuition fees up to date', 'Scholarship holder', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)', 'Unemployment rate', 'GDP',
#        'Target'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier
dctree=DecisionTreeClassifier()

# %%
dctree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score,f1_score,accuracy_score
models = {
    "Logistic": LogisticRegression(solver="liblinear"),
    "DecisionTree": DecisionTreeClassifier(max_depth=5),
    "RandomForest": RandomForestClassifier(n_estimators=100),
    "SVM": SVC(kernel="rbf", probability=True),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric="logloss"),
}

# --- 4. Train & Evaluate ---
results = []
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]
    auc = roc_auc_score(y_test, y_proba)
    f1 = f1_score(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    results.append({
        "model": name,
        "auc": auc,
        "f1": f1,
        "accuracy": acc
    })

results_df = pd.DataFrame(results).sort_values(by="auc", ascending=False)
print(results_df)
# Out:
#           model       auc        f1  accuracy
# 2  RandomForest  0.945809  0.938567  0.910559
# 4       XGBoost  0.937759  0.933333  0.904348
# 0      Logistic  0.933469  0.931271  0.900621
# 3           SVM  0.919477  0.936602  0.906832
# 1  DecisionTree  0.884808  0.924255  0.889441

# %%
# ##Random Forest
# from sklearn.model_selection import GridSearchCV
# rf = RandomForestClassifier(random_state=42)

# # Define the hyperparameter grid
# param_grid = {
#     "n_estimators": [100, 200, 500],        # number of trees
#     "max_depth": [None, 5, 10, 20],         # depth of trees
#     "min_samples_split": [2, 5, 10],        # minimum samples to split a node
#     "min_samples_leaf": [1, 2, 4],          # minimum samples at a leaf
#     "max_features": ["sqrt", "log2", None]  # number of features to consider
# }

# # Setup GridSearchCV
# grid_search = GridSearchCV(
#     estimator=rf,
#     param_grid=param_grid,
#     cv=5,               
#     scoring="accuracy", 
#     n_jobs=-1,           
#     verbose=2
# )


# grid_search.fit(X_train, y_train)

# print("Best Parameters:", grid_search.best_params_)
# print("Best Score:", grid_search.best_score_)

# best_rf = grid_search.best_estimator_

# %%
best_rf
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
from sklearn.pipeline import Pipeline

# %%
model=Pipeline([
    ("Standardization",StandardScaler())
    ,("Model",RandomForestClassifier(n_estimators=100,max_depth=10,random_state=42,criterion='gini'))
])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Standardization', StandardScaler()),
#                 ('Model',
#                  RandomForestClassifier(max_depth=10, random_state=42))])

# %%
y_predict=model.predict(X_test)

# %%
X_test
# Out:
# array([[ 1.39512382,  0.19332466,  0.        , ...,  0.32911221,
#          0.86436529,  0.32872409],
#        [-0.67536003, -0.88073781,  0.        , ...,  0.74452083,
#         -1.55020249,  0.1166294 ],
#        [-0.67536003, -1.41776905,  0.        , ..., -2.03552146,
#          1.47758885, -1.85991254],
#        ...,
#        [-0.67536003,  1.26738714,  0.        , ...,  0.42497574,
#         -1.05195834,  1.55616566],
#        [-0.67536003, -1.14925343,  0.        , ...,  0.98417965,
#          1.47758885, -1.85991254],
#        [-0.67536003, -1.14925343,  0.        , ..., -2.03552146,
#         -0.32375536,  0.75742611]], shape=(805, 21))

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.906832298136646

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
df
# Out:
#       Application order  Course  Daytime/evening attendance  \
# 0                     5       2                           1
# 1                     2      15                           1
# 2                     1      12                           1
# 3                     1      14                           1
# 4                     1      12                           1
# ...                 ...     ...                         ...
# 2432                  1       8                           1
# 2433                  1       5                           1
# 2434                  6      15                           1
# 2435                  1      12                           1
# 2436                  1       9                           1
#
#       Mother's occupation  Father's occupation  Displaced  \
# 0                       6                   10          1
# 1                       6                    4          1
# 2                       8                   11          1
# 3                       6                    8          1
# 4                      10                   10          1
# ...                   ...                  ...        ...
# 2432                    4                    6          1
# 2433                   10                   10          1
# 2434                    6                    5          0
# 2435                   10                   10          1
# 2436                    8                    5          1
#
#       Tuition fees up to date  Scholarship holder  International  \
# 0                           1                   0              0
# 1                           1                   0              0
# 2                           1                   1              0
# 3                           1                   0              0
# 4                           1                   1              0
# ...                       ...                 ...            ...
# 2432                        1                   0              0
# 2433                        1                   1              0
# 2434                        1                   0              0
# 2435                        1                   1              0
# 2436                        1                   1              0
#
#       Curricular units 1st sem (credited)  ...  \
# 0                                       0  ...
# 1                                       0  ...
# 2                                       0  ...
# 3                                       0  ...
# 4                                       0  ...
# ...                                   ...  ...
# 2432                                    0  ...
# 2433                                    0  ...
# 2434                                    0  ...
# 2435                                    0  ...
# 2436                                    0  ...
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.428571
# 2                                       7                         13.300000
# 3                                       6                         12.333333
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.800000
# 2433                                    6                         13.833333
# 2434                                    5                         13.600000
# 2435                                    7                         14.912500
# 2436                                    5                         13.800000
#
#       Curricular units 2nd sem (credited)  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 2432                                    0
# 2433                                    0
# 2434                                    0
# 2435                                    0
# 2436                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       8
# 3                                       6
# 4                                       8
# ...                                   ...
# 2432                                    5
# 2433                                    6
# 2434                                    6
# 2435                                    8
# 2436                                    5
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                         10
# 2                                          8
# 3                                          7
# 4                                          8
# ...                                      ...
# 2432                                       8
# 2433                                       6
# 2434                                       8
# 2435                                       9
# 2436                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       5                         12.400000
# 2                                       8                         14.345000
# 3                                       5                         14.200000
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.600000
# 2433                                    6                         13.500000
# 2434                                    5                         12.666667
# 2435                                    1                         13.500000
# 2436                                    5                         12.000000
#
#       Unemployment rate   GDP  Target
# 0                  10.8  1.74       0
# 1                   9.4 -3.12       1
# 2                  15.5 -4.06       1
# 3                  13.9  0.79       1
# 4                  12.7 -1.70       1
# ...                 ...   ...     ...
# 2432                9.4 -3.12       1
# 2433               16.2 -0.92       1
# 2434               15.5 -4.06       1
# 2435               13.9  0.79       0
# 2436                9.4 -3.12       1
#
# [2437 rows x 22 columns]

# %%
data=df.drop(columns='Target').iloc[:,1:].to_csv('data.csv',index='ignore')
datadf=pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['Application order', 'Course', 'Daytime/evening attendance',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Tuition fees up to date', 'Scholarship holder', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)', 'Unemployment rate', 'GDP',
#        'Target'],
#       dtype='object')

# %%
datadf.iloc[:,1:].to_csv('final_dataset.csv')

# %%
pd.read_csv('final_dataset.csv')
# Out:
#       Unnamed: 0  Course  Daytime/evening attendance  Mother's occupation  \
# 0              0       2                           1                    6
# 1              1      15                           1                    6
# 2              2      12                           1                    8
# 3              3      14                           1                    6
# 4              4      12                           1                   10
# ...          ...     ...                         ...                  ...
# 2432        2432       8                           1                    4
# 2433        2433       5                           1                   10
# 2434        2434      15                           1                    6
# 2435        2435      12                           1                   10
# 2436        2436       9                           1                    8
#
#       Father's occupation  Displaced  Tuition fees up to date  \
# 0                      10          1                        1
# 1                       4          1                        1
# 2                      11          1                        1
# 3                       8          1                        1
# 4                      10          1                        1
# ...                   ...        ...                      ...
# 2432                    6          1                        1
# 2433                   10          1                        1
# 2434                    5          0                        1
# 2435                   10          1                        1
# 2436                    5          1                        1
#
#       Scholarship holder  International  Curricular units 1st sem (credited)  \
# 0                      0              0                                    0
# 1                      0              0                                    0
# 2                      1              0                                    0
# 3                      0              0                                    0
# 4                      1              0                                    0
# ...                  ...            ...                                  ...
# 2432                   0              0                                    0
# 2433                   1              0                                    0
# 2434                   0              0                                    0
# 2435                   1              0                                    0
# 2436                   1              0                                    0
#
#       ...  Curricular units 1st sem (evaluations)  \
# 0     ...                                       0
# 1     ...                                       8
# 2     ...                                       9
# 3     ...                                       6
# 4     ...                                       8
# ...   ...                                     ...
# 2432  ...                                       6
# 2433  ...                                       6
# 2434  ...                                       7
# 2435  ...                                       8
# 2436  ...                                       5
#
#       Curricular units 1st sem (approved)  Curricular units 1st sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.428571
# 2                                       7                         13.300000
# 3                                       6                         12.333333
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.800000
# 2433                                    6                         13.833333
# 2434                                    5                         13.600000
# 2435                                    7                         14.912500
# 2436                                    5                         13.800000
#
#       Curricular units 2nd sem (credited)  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 2432                                    0
# 2433                                    0
# 2434                                    0
# 2435                                    0
# 2436                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       8
# 3                                       6
# 4                                       8
# ...                                   ...
# 2432                                    5
# 2433                                    6
# 2434                                    6
# 2435                                    8
# 2436                                    5
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                         10
# 2                                          8
# 3                                          7
# 4                                          8
# ...                                      ...
# 2432                                       8
# 2433                                       6
# 2434                                       8
# 2435                                       9
# 2436                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       5                         12.400000
# 2                                       8                         14.345000
# 3                                       5                         14.200000
# 4                                       7                         13.214286
# ...                                   ...                               ...
# 2432                                    5                         11.600000
# 2433                                    6                         13.500000
# 2434                                    5                         12.666667
# 2435                                    1                         13.500000
# 2436                                    5                         12.000000
#
#       Unemployment rate   GDP
# 0                  10.8  1.74
# 1                   9.4 -3.12
# 2                  15.5 -4.06
# 3                  13.9  0.79
# 4                  12.7 -1.70
# ...                 ...   ...
# 2432                9.4 -3.12
# 2433               16.2 -0.92
# 2434               15.5 -4.06
# 2435               13.9  0.79
# 2436                9.4 -3.12
#
# [2437 rows x 21 columns]

# %%
model.predict_proba(X_test[0].reshape(1,-1))[0][0]
# Out:
# np.float64(0.07009515742227936)

# %%
model.predict(X_test[0].reshape(1,-1))
# Out:
# array([1])

# %%
df.colu
